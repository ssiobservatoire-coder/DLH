# %% [markdown]
# <a href="https://colab.research.google.com/github/ssiobservatoire-coder/DLH/blob/main/MatrixTransformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Définition des points d'un carré unitaire
square = np.array([[0, 1, 1, 0, 0],
                   [0, 0, 1, 1, 0]])
# Transformation exemple agrandissement facteur 3
#A = np.array([[3, 0],
#              [0,  3]])
# Définition de la matrice de transformation (ex: Rotation de 60)
#definir l'angle en radian à pardir de l'angle en degré np.radians(angle)
# np.cos(angle) and np.sin(angle)
angle =
#fill the gap
B = np.array([[,  ],
              [,  ]])
# défine a shearing transformation
#C=
#B = np.array([[3, 0],
#              [0,  3]])

# 3. Application de la transformation
#transformed_square = A @ square
transformed_square = B @ square
# 4. Affichage
plt.figure(figsize=(6,6))
plt.plot(square[0], square[1], 'b--', label='Original Square')
plt.plot(transformed_square[0], transformed_square[1], 'r-', label='Transformed')
plt.grid(True)
plt.legend()
plt.title("Matrix Transformation in R^2")
plt.show()
