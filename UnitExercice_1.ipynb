# %% [markdown]
# <a href="https://colab.research.google.com/github/ssiobservatoire-coder/DLH/blob/main/UnitExercice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Environment Setup

# %%
import numpy as np
import matplotlib.pyplot as plt

# Définition de l'intervalle de x (ex: de -10 à 10 avec 100 points)
x = np.linspace(-10, 10, 100)

# %% [markdown]
# ## Solve the inequality*
# $2x-2>0$
#
# First fill the gap in the def f(x).

# %%
# Définition de la fonction
def f(x):
    y=
    return y


y = f(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y , label='f(x) = 2x - 2', color='blue', lw=2)

# Ligne y=0 (l'axe des abscisses)
plt.axhline(0, color='black', linewidth=1.5)
plt.axvline(0, color='black', linewidth=1)

# Colorier la zone de solution (f(x) > 0)
plt.fill_between(x, y, 0, where=(y>0 ), color='green', alpha=0.3, label='Zone f(x) > 0')

plt.title("Visualisation de l'inéquation 2x - 4 > 0")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True, linestyle=':')
plt.legend()
plt.show()

# %% [markdown]
# ## Solve the equation
# $2x-2=2x+4$
#
# Fill the gap in def g1(x) and plot the curve and look at the solution

# %%
def g1(x):
    y =
    return y

y2 =
plt.figure(figsize=(10, 6))
plt.plot(x,y, label='f(x) = 2x - 2', color='blue')
plt.plot(x, y2 , label='g1(x) = 2x +4', color='blue')
plt.title("Comparaison de deux fonctions affines")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##Solve the Inequality
# $f(x)<g2(x)$ where $f(x)=2x-2$ and $g2(x)=-x=4$
#
# Fill the gap in def g2(x) and in the line plt.fill_between(..., where(...)...)

# %%
def g2(x):
    y=
    return y
y3 =

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='f(x) = 2x - 2', color='blue')
plt.plot(x, y3, label='g(x) = -x + 4', color='red')

# Colorier là où f(x) est au-dessus de g(x)
plt.fill_between(x, y, y3, where=( ), color='gray', alpha=0.2, label='f(x) > g(x)')

# Trouver le point d'intersection (2x - 2 = -x + 4 => 3x = 6 => x = 2)
plt.scatter([2], [2], color='black', zorder=5)
plt.annotate('Point de bascule (2, 2)', xy=(2, 2), xytext=(4, 1),
             arrowprops=dict(facecolor='black', shrink=0.05))

plt.title("Comparaison de deux fonctions affines")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##Solve the equation and inequality
# $x^2-2=x+1$ and $x^2-2\leq x+1$
#
# Fill the gap in def f(x) and def g(x).
#
# Fill the gap in plt.plot(x, ?, ...)
#
# Fill the gap in plt.fill_between(...)

# %%
def f(x):
    y =
    return y
def g(x):
    y =
    return y

plt.figure(figsize=(10, 6))
plt.plot(x, , label='f(x) = x² - 2 (Quadratique)', color='blue')
plt.plot(x, , label='g(x) = x + 1 (Affine)', color='red')

# Coloration de la zone de solution f(x) <= g(x)
plt.fill_between(x, f(x), g(x), where=( ), color='green', alpha=0.2, label='f(x) <= g(x)')

plt.axhline(0, color='black', lw=1)
plt.title("Inéquation : Parabole vs Droite")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
