# %% [markdown]
# <a href="https://colab.research.google.com/github/ssiobservatoire-coder/DLH/blob/main/GradientVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# Définition de l'intervalle de x (ex: de -10 à 10 avec 100 points)
x = np.linspace(-10, 10, 100)

# %%
x = np.linspace( -5 , 5 , 150 )
y = np.linspace( -5 , 5 , 150 )

a, b = np.meshgrid( x , y )
# C1 is the first equation, C2 the second and C3 ther third fill the gap
C1 =
C2 =
C3 =
figure, axes = plt.subplots()

axes.contour( a , b , C1 , [0] )
axes.contour( a , b , C2 , [0] )
axes.contour( a , b , C3 , [0] )
V = np.array([[0,1]])
origin = np.array([[0, 0, 0],[math.sqrt(3), math.sqrt(5), math.sqrt(10)]]) # origin point
plt.quiver(*origin, V[:,0], V[:,1], color=['r','b','g'], scale=21)
axes.set_aspect( 1 )

plt.title( 'Center-Radius form Circle' )
plt.show()
